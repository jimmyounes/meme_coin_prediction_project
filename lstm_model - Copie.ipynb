# %%
import pandas as pd 
import os 
yes=[]
no=[]

for filename in os.listdir("./clean_database"):
        did_it=False
        filepath = os.path.join("./clean_database", filename)
        dataframe=pd.read_csv(filepath,sep="\t") 
        
        price_at_one_hour_left = dataframe.iloc[29]["token_price_usd"]
                                                   
        if(int(dataframe.iloc[0]["token_market_cap"])<55000 ):
         print(dataframe.iloc[0]["token_market_cap"]) 
         for index in range(1, len(dataframe)):
            price_after_one_hour = dataframe.iloc[index]["token_price_usd"]
            if((price_at_one_hour_left/price_after_one_hour)>=2):
                  
                  yes.append(dataframe.iloc[index]["token_address"])
                  did_it=True
                  break
         if(did_it==False):
              no.append(dataframe.iloc[29]["token_address"])   

print("number of token did a x2",len(yes))
print("number of token didn't a x2",len(no))
# Out:
# 53890
# 54879
# 54379
# 52605
# 50543
# 52401
# 54712
# 54498
# 54024
# 51562
# 53035
# 52057
# 54743
# 50268
# 53736
# 50651
# 54578
# 52629
# 51105
# 54266
# 50712
# 51753
# 53131
# 51462
# number of token did a x2 10
# number of token didn't a x2 14

# %%
import pandas as pd 
dataframeGlobale=pd.DataFrame()
dataframeGlobaleGainners=pd.DataFrame()
dataframeGlobaleLoosers=pd.DataFrame()
for filename in os.listdir("./clean_database"):
        did_it=False
        filepath = os.path.join("./clean_database", filename)
        dataframe=pd.read_csv(filepath,sep="\t") 
        token_adress= dataframe.iloc[29]["token_address"]
        if(token_adress in yes):
                dataframeGlobaleGainners= pd.concat([dataframeGlobaleGainners, dataframe.head(30)], ignore_index=True)
        else : 
                dataframeGlobaleLoosers =pd.concat([dataframeGlobaleLoosers, dataframe.head(30)], ignore_index=True)       

dataframeGlobale=pd.concat([dataframeGlobaleLoosers, dataframeGlobaleGainners], ignore_index=True)
print(dataframeGlobale["token_m5_buys"].mean())
# Out:
# 108.99916666666667

# %%
print("-----------------------------------------------------")
print(dataframeGlobale)
# Out:
# -----------------------------------------------------
#      chain_id   dex_id                                  pair_address  \
# 0      solana  raydium  EnXh6jHyUmkTCTQxdi6zLydS65HA53xrNb28c9oDxfzt
# 1      solana  raydium  EnXh6jHyUmkTCTQxdi6zLydS65HA53xrNb28c9oDxfzt
# 2      solana  raydium  EnXh6jHyUmkTCTQxdi6zLydS65HA53xrNb28c9oDxfzt
# 3      solana  raydium  EnXh6jHyUmkTCTQxdi6zLydS65HA53xrNb28c9oDxfzt
# 4      solana  raydium  EnXh6jHyUmkTCTQxdi6zLydS65HA53xrNb28c9oDxfzt
# ...       ...      ...                                           ...
# 9595   solana  raydium   XwCdAeehZW8nxU2HUaFMnS2fKCkiVjcPBooZ94SJJJZ
# 9596   solana  raydium   XwCdAeehZW8nxU2HUaFMnS2fKCkiVjcPBooZ94SJJJZ
# 9597   solana  raydium   XwCdAeehZW8nxU2HUaFMnS2fKCkiVjcPBooZ94SJJJZ
# 9598   solana  raydium   XwCdAeehZW8nxU2HUaFMnS2fKCkiVjcPBooZ94SJJJZ
# 9599   solana  raydium   XwCdAeehZW8nxU2HUaFMnS2fKCkiVjcPBooZ94SJJJZ
#
#                                      token_address         token_name  \
# ...

# %%
# Out:
#   chain_id   dex_id                                  pair_address  \
# 0   solana  raydium  Cp7iC7dTep3CKfcKSg1m9bnwNX7m547G6bFBWSuFaWSL
# 1   solana  raydium  Cp7iC7dTep3CKfcKSg1m9bnwNX7m547G6bFBWSuFaWSL
# 2   solana  raydium  Cp7iC7dTep3CKfcKSg1m9bnwNX7m547G6bFBWSuFaWSL
# 3   solana  raydium  Cp7iC7dTep3CKfcKSg1m9bnwNX7m547G6bFBWSuFaWSL
# 4   solana  raydium  Cp7iC7dTep3CKfcKSg1m9bnwNX7m547G6bFBWSuFaWSL
#
#                                   token_address     token_name token_symbol  \
# 0  5MXVq99D4hQgziRFeDob6MmbtyczhN3yHUqQu49p7PTX  Lichi the cat       $lichi
# 1  5MXVq99D4hQgziRFeDob6MmbtyczhN3yHUqQu49p7PTX  Lichi the cat       $lichi
# 2  5MXVq99D4hQgziRFeDob6MmbtyczhN3yHUqQu49p7PTX  Lichi the cat       $lichi
# 3  5MXVq99D4hQgziRFeDob6MmbtyczhN3yHUqQu49p7PTX  Lichi the cat       $lichi
# 4  5MXVq99D4hQgziRFeDob6MmbtyczhN3yHUqQu49p7PTX  Lichi the cat       $lichi
#
#    token_m5_buys  token_m5_sells  token_h1_buys  token_h1_sells  ...  \
# ...

# %%
X=[]
Y=[]
for filename in os.listdir("./clean_database"):
        did_it=False
        filepath = os.path.join("./clean_database", filename)
        dataframe=pd.read_csv(filepath,sep="\t") 
        sample= []
        token_adress= dataframe.iloc[29]["token_address"]

        for index in range(0, 5):
                
                sample.append([(dataframe.iloc[index]["token_price_usd"]-dataframe.iloc[0]["token_price_usd"])/dataframe.iloc[0]["token_price_usd"],(dataframe.iloc[index]["token_market_cap"]-dataframeGlobale["token_market_cap"].mean())/dataframeGlobale["token_market_cap"].std(),(dataframe.iloc[index]["token_m5_buys"]-dataframe.iloc[index]["token_m5_sells"])/500,(dataframe.iloc[index]["token_m5_buys"]-dataframeGlobale["token_m5_buys"].mean())/dataframeGlobale["token_m5_buys"].std(),(dataframe.iloc[index]["token_m5_sells"]-dataframeGlobale["token_m5_sells"].mean())/dataframeGlobale["token_m5_sells"].std(),(dataframe.iloc[index]["token_h1_buys"]-dataframeGlobale["token_h1_buys"].mean())/dataframeGlobale["token_m5_buys"].std(),(dataframe.iloc[index]["token_h1_sells"]-dataframeGlobale["token_h1_sells"].mean())/dataframeGlobale["token_h1_sells"].std() ])
        X.append(sample)
        if(token_adress in yes):
                Y.append(1)
        else : 
                Y.append(0)

# %%
from sklearn.model_selection import train_test_split

# Assuming X_seqs is your sequence data and y_labels is the corresponding labels
# X_seqs is a list of sequences
# y_labels is a list of corresponding labels (1 for positive, 0 for negative)

# Split the data into training and test sets with stratified sampling
X_train_seqs, X_test_seqs, y_train_labels, y_test_labels = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense

# Convert X to a numpy array
X_arr = np.array(X_train_seqs)

# Convert y to a numpy array
y_arr = np.array(y_train_labels)

# Define model architecture for binary classification
model = Sequential()
model.add(LSTM(units=150, input_shape=(5,len(X[0][0])), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(units=1, activation='sigmoid'))  # Use sigmoid activation for binary classification

# Compile the model
model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])  # Use binary_crossentropy loss for binary classification

# Train the model
history = model.fit(X_arr, y_arr, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 6s 24ms/step - loss: 0.3595 - accuracy: 0.8945
# Epoch 2/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2117 - accuracy: 0.9492
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1811 - accuracy: 0.9609
# Epoch 4/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1599 - accuracy: 0.9648
# Epoch 5/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1463 - accuracy: 0.9688
# Epoch 6/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1550 - accuracy: 0.9688
# Epoch 7/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1482 - accuracy: 0.9688
# Epoch 8/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1362 - accuracy: 0.9688
# Epoch 9/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1422 - accuracy: 0.9688
# Epoch 10/100
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

X_arr = np.array(X_test_seqs)
predictions = model.predict(X_arr)
binary_predictions = (predictions > 0.5).astype(int)
# If your model outputs probabilities (e.g., if using sigmoid activation in the last layer), 
# you might need to threshold them to get binary predictions
y_arr=y_test_labels
        
predictions=binary_predictions

# Calculate metrics
accuracy = accuracy_score(y_arr, predictions)
precision = precision_score(y_arr, predictions)
recall = recall_score(y_arr, predictions)
f1 = f1_score(y_arr, predictions)

# Print metrics

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# Assuming you have true labels (y_test) and predictions (binary_predictions) ready
report = classification_report(y_arr, predictions, target_names=['Class 0', 'Class 1'])

print("\n")
print(report)
# Out:
# 2/2 [==============================] - 1s 8ms/step
# Accuracy: 0.96875
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
#
#               precision    recall  f1-score   support
#
#      Class 0       0.97      1.00      0.98        62
#      Class 1       0.00      0.00      0.00         2
#
#     accuracy                           0.97        64
#    macro avg       0.48      0.50      0.49        64
# weighted avg       0.94      0.97      0.95        64
# c:\Users\YounèsAITKETTOUT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
if 'sum' in globals() and isinstance(globals()['sum'], int):
    del globals()['sum']

# %%
import shutil
import os 
import datetime
import pandas as pd
token_analysed=[]
while True:
    for filename in os.listdir("./live_data"):
        filepath = os.path.join("./live_data", filename)
       
        if os.path.isfile(filepath):
            with open(filepath, 'r', encoding='utf-8') as file:  # Specify encoding
                line_count = sum(1 for line in file)
                if line_count > 21:
                    file.close()  # Close the file before moving
                    destination_filepath = os.path.join("./live_prediction", filename)
                    shutil.move(filepath, destination_filepath)
                    
    X=[]
    tokens=[]
    Y=[]
    for filename in os.listdir("./live_prediction"):
        did_it=False
        filepath = os.path.join("./live_prediction", filename)
        dataframe=pd.read_csv(filepath,sep="\t") 
        sample= []
        token_adress= dataframe.iloc[1]["token_address"]
        if(token_adress not in token_analysed):
            for index in range(0, 20):
                sample.append([(dataframe.iloc[index]["token_price_usd"]-dataframe.iloc[0]["token_price_usd"])/dataframe.iloc[0]["token_price_usd"],(dataframe.iloc[index]["token_market_cap"]-dataframeGlobale["token_market_cap"].mean())/dataframeGlobale["token_market_cap"].std(),(dataframe.iloc[index]["token_m5_buys"]-dataframe.iloc[index]["token_m5_sells"])/500,(dataframe.iloc[index]["token_m5_buys"]-dataframeGlobale["token_m5_buys"].mean())/dataframeGlobale["token_m5_buys"].std(),(dataframe.iloc[index]["token_m5_sells"]-dataframeGlobale["token_m5_sells"].mean())/dataframeGlobale["token_m5_sells"].std(),(dataframe.iloc[index]["token_h1_buys"]-dataframeGlobale["token_h1_buys"].mean())/dataframeGlobale["token_m5_buys"].std(),(dataframe.iloc[index]["token_h1_sells"]-dataframeGlobale["token_h1_sells"].mean())/dataframeGlobale["token_h1_sells"].std() ])
            X.append(sample)
            tokens.append(token_adress)
            token_analysed.append(token_adress)
        if(len(X)!=0):
            predictions = model.predict(X)
            binary_predictions = (predictions > 0.5).astype(int)
            predictions=binary_predictions
            for i in range(0,len(predictions)):
                
                if(predictions[i]==1):
                    with open('./output/output1.txt', 'a') as f:
                        current_time = datetime.datetime.now()
                        output_line = f"{current_time}: token name predict X2 {tokens[i]}\n"
                        f.write(output_line)
                        print("token name predict X2",tokens[i])
# Out:
# ...
# 1/1 [==============================] - 0s 33ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 32ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 33ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 31ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 33ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 32ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 32ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# 1/1 [==============================] - 0s 33ms/step
# token name predict X2 2a2KtDuDHStmPAtQYWMoZzHh4UUyZQCi2TL3tKW587EM
# ...
